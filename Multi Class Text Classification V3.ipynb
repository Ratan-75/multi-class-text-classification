# %%
import pandas as pd

# %%
df = pd.read_csv("TestCase15K(1).csv")

# %%
col = ["Description", "Category"]

# %%
df = df[col]

# %%
df
# Out:
#                                              Description           Category
# 0      Enable your site visitors to post rich text me...        Development
# 1      Run professional stores, integrated with the r...  Business Software
# 2      Send P2P instant messages and exchange MP3 fil...  Internet Software
# 3                Convert WebM video files to MP4 format.              Video
# 4      Add a menu of optional extra features to the n...            Browser
# 5         Fight wars in real time in the war game in 2D.    Gaming Software
# 6                     Seek, locate, and destroy enemies.    Gaming Software
# 7            Take data from one graph to use in another.  Business Software
# 8      Download videos directly from various video We...              Video
# 9            Make quick and powerful photographic edits.        Photography
# 10     Update Symantec virus definitions and antiviru...  Security Software
# 11                See miniature golf in a whole new way.    Gaming Software
# 12     Protect your system and all removable media ag...  Security Software
# 13              Offline Usenet newsgroups & mail reader.            Browser
# 14     Provide newsreader with NZB and RAR support, p...            Browser
# 15     Store and manage up to 5GB of files online for...  Internet Software
# 16     Make a database of your frequently used phrase...   Desktop Software
# 17     Take to the ice and be the hero with this hock...    Gaming Software
# 18     Feel the power of commanding a modern jet figh...    Gaming Software
# 19     Customize the appearance and functionality of ...   Desktop Software
# 20     Edit your images, apply graphic effects, and c...        Photography
# 21     Read and write from parallel and serial ports ...        Development
# 22              Monitor and control Internet activities.  Security Software
# 23     Convert video files and perform basic video ed...              Video
# 24     Back up your critical information to DVDs, CDs...          Utilities
# 25                  Write and publish your own Web logs.        Development
# 26             Code/decode the digitized speech signals.        Development
# 27     Take on the world's most illustrious club side...    Gaming Software
# 28     Update device drivers, improve system compatib...          Utilities
# 29     Expand and decode files downloaded from the We...          Utilities
# ...                                                  ...                ...
# 13856                   Record real-time in-game movies.              Video
# 13857  Protect your privacy and bypass Internet restr...  Security Software
# 13858  Manage the operations and billing for your Int...  Business Software
# 13859  Save the data that you enter into a PDF form, ...  Business Software
# 13860                              Search Google easily.   Desktop Software
# 13861       Automate your computer's tasks or processes.   Desktop Software
# 13862  Control 3D replicas of RC planes and helicopte...    Gaming Software
# 13863  Split and convert video file in one process an...              Video
# 13864  Fix a black screen video problem with this upd...    Gaming Software
# 13865  Share single mouse and keyboard between multip...   Desktop Software
# 13866            Convert from AVI to GIF and vice versa.        Photography
# 13867  Compress the file size of one or more TIFF fil...        Photography
# 13868  Shoot, edit, and share all of life's adventure...              Video
# 13869  Limit children's access to objectionable Web s...  Security Software
# 13870  Process JPEG, PNG, BMP, and GIF files in batch...        Photography
# 13871  Download this feature-packed instant messenger...      Communication
# 13872      Compare files in binary format and edit them.        Development
# 13873  Summon creatures and cast spells to reduce you...    Gaming Software
# 13874               Automate keyboard and mouse actions.          Utilities
# 13875      Use live wallpapers on your Windows desktop.    Desktop Software
# 13876  Build your village, raise a clan, and compete ...    Gaming Software
# 13877  Download big stories automatically by entering...  Internet Software
# 13878      View NBA schedules, results, and live scores.   Desktop Software
# 13879                       Reveal the codes in MS Word.  Business Software
# 13880  Create calendars for any year with customized ...  Business Software
# 13881         Protect your privacy online while surfing.  Internet Software
# 13882  Convert most popular video formats between eac...              Video
# 13883  Convert various video files into iPod-compatib...              Video
# 13884  Show your concern for the climate change with ...   Desktop Software
# 13885   Read PDF files with this lightweight PDF viewer.  Business Software
#
# [13886 rows x 2 columns]

# %%
df["Category_id"] = df['Category'].factorize()[0]

# %%
category_id_df = df[["Category", "Category_id"]].drop_duplicates().sort_values('Category_id')

# %%
category_to_id = dict(category_id_df.values)

# %%
id_to_category = dict(category_id_df[['Category_id', 'Category']].values)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(sublinear_tf = True, min_df = 5, 
                        norm = 'l2', ngram_range = (1,2), 
                        stop_words = 'english', max_features = 12)

# %%
features = tfidf.fit_transform(df.Description).toarray()

# %%
labels = df.Category_id

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Description'],df['Category'], 
                                                    test_size = 0.1, random_state=3)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vect = CountVectorizer()

# %%
X_train_count = count_vect.fit_transform(X_train)
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_count)

# %%
from sklearn.svm import LinearSVC
classification = LinearSVC().fit(X_train_tfidf, y_train)

# %%
y_pred = classification.predict(count_vect.transform(X_test))

# %%
from sklearn import metrics

# %%
print(metrics.classification_report(y_test, y_pred, labels = df.Category, 
                                    target_names = df['Category'].unique()))
# Out:
#                      precision    recall  f1-score   support
#
#         Development       0.70      0.72      0.71       126
#   Business Software       0.73      0.57      0.64       107
#   Internet Software       0.50      0.60      0.54       131
#               Video       0.68      0.88      0.76       113
#             Browser       0.64      0.59      0.61        92
#     Gaming Software       0.94      0.85      0.90       170
#         Photography       0.94      0.85      0.90       170
#   Security Software       0.73      0.57      0.64       107
#    Desktop Software       0.68      0.88      0.76       113
#           Utilities       0.83      0.79      0.81       205
# Networking Software       0.58      0.73      0.64        81
#       Communication       0.94      0.85      0.90       170
#
#           micro avg       0.75      0.73      0.74   1966948
#           macro avg       0.72      0.70      0.71   1966948
#        weighted avg       0.76      0.73      0.74   1966948
